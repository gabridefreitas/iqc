# %% [markdown]
# # Transformada Quântica de Fourier (QFT) com Qiskit
#
# Este notebook demonstra como implementar a Transformada Quântica de Fourier (QFT) usando Qiskit, uma biblioteca popular para computação quântica.
#
# ## Grupo
#
# - Gabriel de Freitas Adolfo
# - Gabriel Serratt
# - Luis Dorr

# %%
# pip install qiskit
# pip install qiskit-aer
# pip install qiskit-ibm-runtime

# %%
import qiskit
print("Qiskit version:", qiskit.__version__)
# Out:
# Qiskit version: 2.2.2

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.x(qreg_q[3])
circuit.x(qreg_q[2])
circuit.x(qreg_q[0])
circuit.h(qreg_q[3])
circuit.cp(pi / 2, qreg_q[2], qreg_q[3])
circuit.cp(pi / 4, qreg_q[1], qreg_q[3])
circuit.cp(pi / 8, qreg_q[0], qreg_q[3])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
circuit.h(qreg_q[2])
circuit.cp(pi / 2, qreg_q[1], qreg_q[2])
circuit.cp(pi / 4, qreg_q[0], qreg_q[2])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
circuit.h(qreg_q[1])
circuit.cp(pi / 2, qreg_q[0], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
circuit.h(qreg_q[0])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
circuit.swap(qreg_q[0], qreg_q[3])
circuit.swap(qreg_q[1], qreg_q[2])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
circuit.measure(qreg_q[3], creg_c[3])
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[2], creg_c[2])
circuit.measure(qreg_q[0], creg_c[0])

print(circuit)
# Out:
#      ┌───┐                                 ░                         ░      »
# q_0: ┤ X ├────────────────────────■────────░────────────────■────────░──────»
#      └───┘                        │        ░                │        ░ ┌───┐»
# q_1: ────────────────────■────────┼────────░───────■────────┼────────░─┤ H ├»
#      ┌───┐               │        │        ░ ┌───┐ │P(π/2)  │P(π/4)  ░ └───┘»
# q_2: ┤ X ├──────■────────┼────────┼────────░─┤ H ├─■────────■────────░──────»
#      ├───┤┌───┐ │P(π/2)  │P(π/4)  │P(π/8)  ░ └───┘                   ░      »
# q_3: ┤ X ├┤ H ├─■────────■────────■────────░─────────────────────────░──────»
#      └───┘└───┘                            ░                         ░      »
# c: 4/═══════════════════════════════════════════════════════════════════════»
#                                                                             »
# «               ░ ┌───┐ ░        ░          ┌─┐
# «q_0: ─■────────░─┤ H ├─░──X─────░──────────┤M├
# ...
